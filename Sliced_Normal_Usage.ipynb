# %% [markdown]
# # Setup

# %%
# !rm -rf Sliced_Normal
# !git clone https://github.com/Arindam-97/Sliced_Normal.git
# %cd Sliced_Normal
# Out:
# Cloning into 'Sliced_Normal'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 40 (delta 14), reused 24 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (40/40), 27.88 KiB | 713.00 KiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/Sliced_Normal

# %%
import os
os.chdir('/content/Sliced_Normal') # change this to folder where package cloned

# %%
# !pip install -r requirements.txt
# !pip install -e sliced_normals
# Out:
# Requirement already satisfied: pymanopt in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: emcee in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pymanopt->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: scipy!=1.10.*,!=1.11.*,!=1.12.*,>=1.0 in /usr/local/lib/python3.11/dist-packages (from pymanopt->-r requirements.txt (line 1)) (1.15.3)
# Obtaining file:///content/Sliced_Normal/sliced_normals
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pymanopt in /usr/local/lib/python3.11/dist-packages (from sliced_normals==0.1) (2.2.1)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from sliced_normals==0.1) (1.8.0)
# Requirement already satisfied: emcee in /usr/local/lib/python3.11/dist-packages (from sliced_normals==0.1) (3.1.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from sliced_normals==0.1) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from sliced_normals==0.1) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from sliced_normals==0.1) (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sliced_normals==0.1) (1.6.1)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.11/dist-packages (from autograd->sliced_normals==0.1) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->sliced_normals==0.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->sliced_normals==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->sliced_normals==0.1) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->sliced_normals==0.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->sliced_normals==0.1) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->sliced_normals==0.1) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->sliced_normals==0.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->sliced_normals==0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->sliced_normals==0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->sliced_normals==0.1) (2025.2)
# Requirement already satisfied: scipy!=1.10.*,!=1.11.*,!=1.12.*,>=1.0 in /usr/local/lib/python3.11/dist-packages (from pymanopt->sliced_normals==0.1) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sliced_normals==0.1) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sliced_normals==0.1) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->sliced_normals==0.1) (1.17.0)
# Installing collected packages: sliced_normals
#   Running setup.py develop for sliced_normals
# Successfully installed sliced_normals-0.1

# %%
# !ls sliced_normals
# Out:
# features.py  likelihood.py    Sample_Data.csv
# fmle.py      mcmc.py	      setup.py
# __init__.py  optimization.py  sliced_normals.egg-info

# %%
import sliced_normals as SN
from sliced_normals.fmle import get_FMLE
from sliced_normals.optimization import estimate_optimal_B
from sliced_normals.mcmc import run_mcmc_sampler
from sliced_normals.likelihood import evaluate_true_log_likelihood

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
data = pd.read_csv("sliced_normals/Sample_Data.csv")[['X_1','X_2','X_3']]
sns.pairplot(data, plot_kws={'s': 5})

# %% [markdown]
# # Get FMLE

# %%
d = 2
B_fmle = get_FMLE(data, d)
evaluate_true_log_likelihood(data, B_fmle, d, n_grid=1000000)
# Out:
# np.float64(-5.019049034216916)

# %% [markdown]
# # Get Data MLE

# %%
max_iter = 2000
min_grad_norm=5e-4

B_opt = estimate_optimal_B(data, degree=2, n_grid=5000, verbosity=1, penalty_lambda = 0,max_iterations = max_iter, min_gradient_norm = min_grad_norm)
# Out:
# Optimizing...
# Terminated - min grad norm reached after 898 iterations, 6.81 seconds.

# %%
evaluate_true_log_likelihood(data, B_opt, d, n_grid=1000000)
# Out:
# np.float64(-3.095766514035279)

# %% [markdown]
# # Run MCMC

# %%
# True MLE
samples_df = run_mcmc_sampler(data, B=B_opt, d=2, num_samples=2000, burnin=300, thin=5)
# Out:
# 100%|██████████| 2000/2000 [00:01<00:00, 1214.92it/s]

# %%
# F-MLE
samples_df_FMLE = run_mcmc_sampler(data, B=B_fmle, d=2, num_samples=2000, burnin=300, thin=5)
# Out:
# 100%|██████████| 2000/2000 [00:01<00:00, 1211.47it/s]

# %% [markdown]
# # Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# First pairplot: original data
g1 = sns.pairplot(data, plot_kws={'s': 5})
g1.fig.suptitle("Data", y=1.02)

# Save axis limits
lims = {}
for i, row_axes in enumerate(g1.axes):
    for j, ax in enumerate(row_axes):
        if ax:  # skip empty axes
            lims[(i, j)] = (ax.get_xlim(), ax.get_ylim())

# %%
# Second pairplot: first sample
g2 = sns.pairplot(samples_df, plot_kws={'s': 5})
g2.fig.suptitle("True MLE Samples", y=1.02)

# Apply saved limits
for i, row_axes in enumerate(g2.axes):
    for j, ax in enumerate(row_axes):
        if ax and (i, j) in lims:
            ax.set_xlim(lims[(i, j)][0])
            ax.set_ylim(lims[(i, j)][1])

# %%
# Third pairplot: another sample (or same if repeating)
g3 = sns.pairplot(samples_df_FMLE, plot_kws={'s': 5})
g3.fig.suptitle("FMLE_Samples", y=1.02)

# Apply same limits again
for i, row_axes in enumerate(g3.axes):
    for j, ax in enumerate(row_axes):
        if ax and (i, j) in lims:
            ax.set_xlim(lims[(i, j)][0])
            ax.set_ylim(lims[(i, j)][1])
